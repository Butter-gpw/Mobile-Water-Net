# %%
from Under_Water_index import Under_Water_index_Proceesing

# %%
tested_path=''  # path to tested images folder
ref_path = '' # path to reference images folder

# %%
uwip = Under_Water_index_Proceesing(tested_path,ref_path, img_size=(512,512))

# %%
uwip.calculate()
# Out:
# 100%|██████████| 856/856 [07:50<00:00,  1.82it/s]

# %%
uwip.form
# Out:
#      name  mean_squared_error  peak_signal_noise_ratio      ssim      UIQM
# 0    1000          271.789717                23.788473  0.803537  3.436436  \
# 1    1006          239.816897                24.332006  0.758685  3.303274
# 2    1015          626.913172                20.158730  0.847156  2.705890
# 3     102          114.604277                27.538795  0.909699  2.954657
# 4    1022          791.998112                19.143562  0.769054  3.334485
# ..    ...                 ...                      ...       ...       ...
# 851    98          269.879086                23.819111  0.862333  3.307788
# 852   982          394.025485                22.175560  0.781760  3.325655
# 853   985          256.490451                24.040092  0.845453  3.464857
# 854   998          268.953911                23.834025  0.794923  3.530288
# 855   999           82.780547                28.951521  0.919093  2.493693
#
#         uciqe
# 0    0.592627
# 1    0.596438
# 2    0.576797
# 3    0.650371
# 4    0.521413
# ..        ...
# 851  0.613078
# 852  0.466428
# 853  0.582283
# 854  0.578985
# 855  0.629696
#
# [856 rows x 6 columns]

# %%
uwip.form.describe()
# Out:
#        mean_squared_error  peak_signal_noise_ratio        ssim        UIQM
# count          856.000000               856.000000  856.000000  856.000000  \
# mean           265.850789                24.988936    0.837248    2.890287
# std            236.277741                 3.005850    0.086826    0.397084
# min             24.291894                14.441086    0.413568    1.064563
# 25%            131.961055                23.128139    0.776054    2.673287
# 50%            203.550777                25.044076    0.846471    2.961594
# 75%            316.422000                26.926357    0.915826    3.177304
# max           2338.685354                34.276190    0.971141    3.603882
#
#             uciqe
# count  856.000000
# mean     0.593123
# std      0.045124
# min      0.426269
# 25%      0.561300
# 50%      0.593919
# 75%      0.627780
# max      0.710620

# %%
uwip.form.to_csv('result.csv',index=False)
uwip.form.describe().to_csv('result_describe.csv')
